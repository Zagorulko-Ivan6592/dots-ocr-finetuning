# %% [markdown]
# # dots.ocr: Обработка PDF

# %%
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install -q transformers accelerate qwen-vl-utils
# !pip install -q pillow tqdm pymupdf pandas markdown pydantic openai requests
# !pip install -q typing-extensions>=4.12.2
print("Зависимости установлены")
# Out:
# Зависимости установлены

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
if device == "cuda":
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Память: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    print(f"Занято: {torch.cuda.memory_reserved(0) / 1e9:.2f} GB")
    print(f"Свободно: {(torch.cuda.get_device_properties(0).total_memory - torch.cuda.memory_reserved(0)) / 1e9:.2f} GB")
else:
    print("WARNING: GPU не обнаружен, используется CPU")
# Out:
# GPU: NVIDIA A100-SXM4-80GB
# Память: 85.1 GB
# Занято: 0.00 GB
# Свободно: 85.10 GB

# %% [markdown]
# ## Конфигурация

# %%
BASE_MODEL_PATH = "/home/jovyan/kurkin/geo_bench_zagorulko/OCR/DotsOCR"
PDF_PATH = "/home/jovyan/kurkin/geo_bench_zagorulko/OCR/data/TAR_ie_2023_12_06.pdf"
OUT_DIR = "/home/jovyan/kurkin/geo_bench_zagorulko/OCR/outputs"
DOTS_OCR_PATH = "/home/jovyan/kurkin/geo_bench_zagorulko/OCR/dots_ocr"

DPI = 260
PROMPT_MODE = "prompt_layout_all_en"  # prompt_layout_all_en, prompt_ocr, prompt_layout_only_en
MAX_NEW_TOKENS = 24000
USE_FAST_INFERENCE = True

USE_VLLM = True
VLLM_SERVER_IP = "localhost"
VLLM_SERVER_PORT = 8000
VLLM_PROTOCOL = "http"
VLLM_MODEL_NAME = "/home/jovyan/kurkin/geo_bench_zagorulko/OCR/DotsOCR"

from pathlib import Path
Path(OUT_DIR).mkdir(parents=True, exist_ok=True)

errors = []
for name, path in [("PDF", PDF_PATH), ("Model", BASE_MODEL_PATH), ("dots.ocr", DOTS_OCR_PATH)]:
    exists = Path(path).exists()
    print(f"{name}: {'OK' if exists else 'ERROR'}")
    if not exists:
        errors.append(f"{name}: {path}")

if errors:
    raise FileNotFoundError(f"Не найдены пути: {errors}")

print(f"\nРежим: {'vLLM' if USE_VLLM else 'HF Transformers'}")
# Out:
# PDF: OK
# Model: OK
# dots.ocr: OK
#
# Режим: vLLM

# %% [markdown]
# ## Подключение dots.ocr

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path(DOTS_OCR_PATH)))

try:
    import dots_ocr
except ImportError:
    import subprocess
    subprocess.run(["pip", "install", "-e", str(DOTS_OCR_PATH)], check=False)

try:
    from dots_ocr import DotsOCRParser
except ImportError:
    from dots_ocr.parser import DotsOCRParser

print("dots.ocr подключен")
# Out:
# dots.ocr подключен

# %% [markdown]
# ## Создание парсера

# %%
if USE_VLLM:
    try:
        import requests
        test_url = f"{VLLM_PROTOCOL}://{VLLM_SERVER_IP}:{VLLM_SERVER_PORT}/health"
        response = requests.get(test_url, timeout=2)
        if response.status_code == 200:
            print("vLLM сервер доступен")
        else:
            print(f"WARNING: vLLM сервер статус {response.status_code}")
    except Exception as e:
        print(f"WARNING: vLLM сервер недоступен: {e}")
    
    parser = DotsOCRParser(
        protocol=VLLM_PROTOCOL, ip=VLLM_SERVER_IP, port=VLLM_SERVER_PORT,
        model_name=VLLM_MODEL_NAME, use_hf=False,
        dpi=DPI, output_dir=OUT_DIR, num_thread=4
    )
    print("Парсер с vLLM готов")
else:
    parser = DotsOCRParser(use_hf=True, dpi=DPI, output_dir=OUT_DIR)
    print("Парсер с HF Transformers готов")
# Out:
# vLLM сервер доступен
# use vllm model, num_thread will be set to 4
# Парсер с vLLM готов

# %% [markdown]
# ## Обработка PDF

# %%
result = parser.parse_file(PDF_PATH, prompt_mode=PROMPT_MODE, fitz_preprocess=False)
print(f"\nГотово! Результаты в {OUT_DIR}")
# Out:
# loading pdf: /home/jovyan/kurkin/geo_bench_zagorulko/OCR/data/TAR_ie_2023_12_06.pdf
# Parsing PDF with 42 pages using 4 threads...
# Processing PDF pages: 100%|██████████| 42/42 [03:54<00:00,  5.57s/it]
# cells post process error: Unterminated string starting at: line 1 column 63 (char 62), when using prompt_layout_all_en
# 🔧 Cleaning String data - Case 0
#   Original length: 24,596
#     ⚠️ Only 1 dict objects found, skipping truncation to avoid deleting all content
#     ❌ JSON parsing failed: Unterminated string starting at: line 1 column 63 (char 62)
#     🔧 Special fix: single incomplete dict → {'bbox': [36, 189, 2979, 1953], 'category': 'Table', 'text': '<table><tr><td>2.1.8.</td><td></td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td>2.1.8.</td><td> ...
#   ✅ Cleaning complete: 1 objects
#     📊 Data length 1 <= 1, skipping deduplication check
# Parsing finished, results saving to /home/jovyan/kurkin/geo_bench_zagorulko/OCR/outputs/TAR_ie_2023_12_06
#
# Готово! Результаты в /home/jovyan/kurkin/geo_bench_zagorulko/OCR/outputs

# %%
# !pip install weasyprint
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting weasyprint
#   Downloading weasyprint-66.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting pydyf>=0.11.0 (from weasyprint)
#   Downloading pydyf-0.11.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: cffi>=0.6 in /home/user/conda/lib/python3.11/site-packages (from weasyprint) (1.17.1)
# Collecting tinyhtml5>=2.0.0b1 (from weasyprint)
#   Downloading tinyhtml5-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: tinycss2>=1.4.0 in /home/user/conda/lib/python3.11/site-packages (from weasyprint) (1.4.0)
# Collecting cssselect2>=0.8.0 (from weasyprint)
#   Downloading cssselect2-0.8.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting Pyphen>=0.9.1 (from weasyprint)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: Pillow>=9.1.0 in /home/user/conda/lib/python3.11/site-packages (from weasyprint) (12.0.0)
# Requirement already satisfied: fonttools>=4.0.0 in /home/user/conda/lib/python3.11/site-packages (from fonttools[woff]>=4.0.0->weasyprint) (4.56.0)
# Requirement already satisfied: pycparser in /home/user/conda/lib/python3.11/site-packages (from cffi>=0.6->weasyprint) (2.22)
# Requirement already satisfied: webencodings in /home/user/conda/lib/python3.11/site-packages (from cssselect2>=0.8.0->weasyprint) (0.5.1)
# Requirement already satisfied: brotli>=1.0.1 in /home/user/conda/lib/python3.11/site-packages (from fonttools[woff]>=4.0.0->weasyprint) (1.0.9)
# Collecting zopfli>=0.1.4 (from fonttools[woff]>=4.0.0->weasyprint)
#   Downloading zopfli-0.2.3.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.9 kB)
# Downloading weasyprint-66.0-py3-none-any.whl (301 kB)
# Downloading cssselect2-0.8.0-py3-none-any.whl (15 kB)
# Downloading pydyf-0.11.0-py3-none-any.whl (8.1 kB)
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 44.3 MB/s eta 0:00:00
# Downloading tinyhtml5-2.0.0-py3-none-any.whl (39 kB)
# Downloading zopfli-0.2.3.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (850 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 850.6/850.6 kB 390.0 MB/s eta 0:00:00
# Installing collected packages: zopfli, tinyhtml5, Pyphen, pydyf, cssselect2, weasyprint
# Successfully installed Pyphen-0.17.2 cssselect2-0.8.0 pydyf-0.11.0 tinyhtml5-2.0.0 weasyprint-66.0 zopfli-0.2.3.post1

# %%
from pathlib import Path
import re
import markdown as md

pdf_filename = Path(PDF_PATH).stem
save_dir = Path(OUT_DIR) / pdf_filename
md_files = list(save_dir.glob("*.md")) if save_dir.exists() else []

def extract_page_num(filename):
    match = re.search(r'_page_(\d+)', filename.stem)
    return int(match.group(1)) if match else 999

valid_md_files = [f for f in md_files if not f.name.endswith("_nohf.md")]
valid_md_files.sort(key=extract_page_num)

if valid_md_files:
    combined_md = []
    combined_md.append(f"# {pdf_filename}\n\n")
    combined_md.append(f"*Объединенный документ из {len(valid_md_files)} страниц*\n\n")
    combined_md.append("---\n\n")
    
    for i, md_file in enumerate(valid_md_files, 1):
        page_num = extract_page_num(md_file)
        content = md_file.read_text(encoding="utf-8")
        combined_md.append(f"## Страница {page_num}\n\n")
        combined_md.append(content)
        combined_md.append("\n\n---\n\n")
    
    combined_md_text = "".join(combined_md)
    combined_md_path = Path(OUT_DIR) / f"{pdf_filename}_combined.md"
    combined_md_path.write_text(combined_md_text, encoding="utf-8")
    print(f"Объединено {len(valid_md_files)} страниц в Markdown")
    print(f"Markdown сохранен: {combined_md_path}")
    
    html_content = md.markdown(combined_md_text, extensions=["tables", "fenced_code", "codehilite"])
    html_with_style = f"""<!DOCTYPE html>
<html>
<head>
    <meta charset="utf-8">
    <style>
        body {{ font-family: Arial, sans-serif; margin: 40px; line-height: 1.6; }}
        table {{ border-collapse: collapse; width: 100%; margin: 20px 0; }}
        th, td {{ border: 1px solid #ddd; padding: 8px; text-align: left; }}
        th {{ background-color: #f2f2f2; }}
        code {{ background-color: #f4f4f4; padding: 2px 4px; border-radius: 3px; }}
        pre {{ background-color: #f4f4f4; padding: 10px; border-radius: 5px; overflow-x: auto; }}
    </style>
</head>
<body>
{html_content}
</body>
</html>"""
    
    html_path = Path(OUT_DIR) / f"{pdf_filename}_combined.html"
    html_path.write_text(html_with_style, encoding="utf-8")
    print(f"HTML сохранен: {html_path}")
    
    try:
        import weasyprint
        pdf_path = Path(OUT_DIR) / f"{pdf_filename}_reconstructed.pdf"
        weasyprint.HTML(string=html_with_style).write_pdf(pdf_path)
        print(f"PDF восстановлен: {pdf_path}")
    except ImportError:
        print("weasyprint не установлен, пропускаем создание PDF")
        print("Установите: pip install weasyprint")
        print("Или откройте HTML файл в браузере для проверки")
    except Exception as e:
        print(f"Ошибка при создании PDF: {e}")
        print("Откройте HTML файл в браузере для проверки")
else:
    print("Markdown файлы не найдены")
# Out:
# Объединено 42 страниц в Markdown
# Markdown сохранен: /home/jovyan/kurkin/geo_bench_zagorulko/OCR/outputs/TAR_ie_2023_12_06_combined.md
# HTML сохранен: /home/jovyan/kurkin/geo_bench_zagorulko/OCR/outputs/TAR_ie_2023_12_06_combined.html
# PDF восстановлен: /home/jovyan/kurkin/geo_bench_zagorulko/OCR/outputs/TAR_ie_2023_12_06_reconstructed.pdf
